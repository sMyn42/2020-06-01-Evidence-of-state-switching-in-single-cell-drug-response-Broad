# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
import plotnine as gg
import umap
from pathlib import Path
import scipy.linalg

# %%
outpath = os.path.join(top_dir, "Figures")

# %% [markdown]
# ## loading data

# %%
top_dir = os.path.dirname(os.getcwd())
proj_dir = 'data'


class load_data:
    
    
    def __init__(self,top_dir,proj_dir):
        
        self.top_dir = top_dir
        self.proj_dir = proj_dir
    
    
    def csvpath(self):
        path = os.path.join(self.top_dir, self.proj_dir, "backend")
        plates = [pl for pl in os.listdir(path)]
        csvpath = [os.path.join(path, pl, pl + "_dmso.csv") for pl in plates]  
        
        return csvpath

    
    def featlist(self):
        path = os.path.join(self.top_dir, self.proj_dir,"metadata","input", "feature_list.txt")
        featlist = np.loadtxt(str(path), dtype=str).tolist()
        return featlist
    
    
    
    
subclass = load_data(top_dir, proj_dir)

csvlist = subclass.csvpath()

featlist = subclass.featlist()

# %%
metalist = ['Image_FileName_OrigMito',
 'Image_FileName_OrigER',
 'Image_PathName_OrigER',
 'Metadata_mg_per_ml',
 'Image_PathName_OrigDNA',
 'Image_PathName_OrigRNA',
 'Image_PathName_OrigMito',
 'Image_FileName_OrigDNA',
 'Image_FileName_OrigRNA',
 'Metadata_broad_sample',
 'Image_Metadata_Well',
 'Metadata_plate_map_name',
 'Metadata_mmoles_per_liter',
 'Image_FileName_CellOutlines',
 'Image_Metadata_Site',
 'Metadata_Plate',
 'Image_FileName_OrigAGP',
 'Image_PathName_CellOutlines',
 'Image_PathName_OrigAGP',
 'Cells_Location_Center_X',
 'Cells_Location_Center_Y',
 'Nuclei_Location_Center_X',
 'Nuclei_Location_Center_Y',
 'Cytoplasm_Location_Center_X',
 'Cytoplasm_Location_Center_Y',
 'ObjectNumber']

# %% [markdown]
# ### Data Preprocessing

# %%
combined = []


for csv in csvlist:
    dmso = pd.read_csv(csv)
    
    metadata = (dmso.loc[:, metalist]
            .rename(columns={'Cells_Location_Center_X':'Metadata_Cells_Location_Center_X',
                            'Cells_Location_Center_Y':'Metadata_Cells_Location_Center_Y',
                            'Nuclei_Location_Center_X':'Metadata_Nuclei_Location_Center_X',
                            'Nuclei_Location_Center_Y':'Metadata_Nuclei_Location_Center_Y',
                            'Cytoplasm_Location_Center_X':'Metadata_Cytoplasm_Location_Center_X',
                            'Cytoplasm_Location_Center_Y':'Metadata_Cytoplasm_Location_Center_Y',
                            'ObjectNumber': 'Metadata_ObjectNumber'})
           )
    metadata.columns = metadata.columns.str.replace('Image_', "Metadata_")
    
    df_var = dmso.loc[:, featlist]
    
    ### Z normalized features
    
    scale = StandardScaler()

    scaled_data = scale.fit_transform(df_var.values)

    df = pd.DataFrame(scaled_data, columns= df_var.columns)
      
    comb = metadata.merge(df, left_index=True, right_index=True)
  
    combined.append(comb)
   
final = pd.concat(combined)

final.shape
# Out:
# (319967, 497)

# %% [markdown]
# ### UMAP Fitting of normalized data

# %%
fumap = []
for csv in csvlist:
    dmso = pd.read_csv(csv)
    
    metadata = (dmso.loc[:, metalist]
            .rename(columns={'Cells_Location_Center_X':'Metadata_Cells_Location_Center_X',
                            'Cells_Location_Center_Y':'Metadata_Cells_Location_Center_Y',
                            'Nuclei_Location_Center_X':'Metadata_Nuclei_Location_Center_X',
                            'Nuclei_Location_Center_Y':'Metadata_Nuclei_Location_Center_Y',
                            'Cytoplasm_Location_Center_X':'Metadata_Cytoplasm_Location_Center_X',
                            'Cytoplasm_Location_Center_Y':'Metadata_Cytoplasm_Location_Center_Y',
                            'ObjectNumber': 'Metadata_ObjectNumber'})
           )
    metadata.columns = metadata.columns.str.replace('Image_', "Metadata_")
    
    df_var = dmso.loc[:, featlist].values
    
    # Z normalized features
    
    scale = StandardScaler()

    scaled_data = scale.fit_transform(df_var)
    
    reducer = umap.UMAP()
    embedding = reducer.fit_transform(scaled_data)
    test = pd.DataFrame(embedding, columns= ['UMAP-1', 'UMAP-2'])
    comb = test.merge(metadata, left_index=True, right_index=True)  
  
    fumap.append(comb)
   
final_umap = pd.concat(fumap)

# %% [markdown]
# ### Plotting

# %%
p = gg.ggplot(final_umap, gg.aes(x='UMAP-1', y='UMAP-2', color= 'Metadata_Plate')) + \
    gg.geom_point(size = 0.003) + \
    gg.xlab("UMAP-1") + \
    gg.ylab("UMAP-2") + \
    gg.ggtitle("UMAP visualization of DMSO's single cell data") + \
     gg.theme_bw() + \
    gg.scale_colour_manual(name= "Platemap", labels=['SQ00015201', 'SQ00015142', 'SQ00015143', 'SQ00015144', 'SQ00015145'], 
                           values = ["#d95f0e", "#fec44f", "#2c7fb8", "#7fcdbb", '#636363'])
    
   


    

gg.ggsave(filename='Modes_DMSO_UMAP.png', plot = p, path = outpath)

p
# Out:
# /Users/habbasi/plotnine/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /Users/habbasi/plotnine/plotnine/ggplot.py:730: PlotnineWarning: Filename: /Users/habbasi/Documents/Github/broadinstitute/2020-06-01-Evidence-of-state-switching-in-single-cell-drug-response-Broad/Figures/Modes_DMSO_UMAP.png
# <ggplot: (7025866925)>

# %% [markdown]
# ## Whitening function

# %%
def whitening_transform(X, lambda_, rotate=True):
    C = (1/X.shape[0]) * np.dot(X.T, X)
    s, V = scipy.linalg.eigh(C)
    D = np.diag( 1. / np.sqrt(s + lambda_) )
    W = np.dot(V, D)
    if rotate:
        W = np.dot(W, V.T)
    return W

def whiten(X, mu, W):
    return np.dot( X - mu, W)

DO_WHITENING = True
REG_PARAM = 1e-6

# %% [markdown]
# ### UMAP Fitting of Whitened data

# %%
wh_umap = []
for csv in csvlist:
    dmso = pd.read_csv(csv)
    
    metadata = (dmso.loc[:, metalist]
            .rename(columns={'Cells_Location_Center_X':'Metadata_Cells_Location_Center_X',
                            'Cells_Location_Center_Y':'Metadata_Cells_Location_Center_Y',
                            'Nuclei_Location_Center_X':'Metadata_Nuclei_Location_Center_X',
                            'Nuclei_Location_Center_Y':'Metadata_Nuclei_Location_Center_Y',
                            'Cytoplasm_Location_Center_X':'Metadata_Cytoplasm_Location_Center_X',
                            'Cytoplasm_Location_Center_Y':'Metadata_Cytoplasm_Location_Center_Y',
                            'ObjectNumber': 'Metadata_ObjectNumber'})
           )
    
    metadata.columns = metadata.columns.str.replace('Image_', "Metadata_")
    
    df_var = dmso.loc[:, featlist].values
    
    # Z normalized features
    
    scale = StandardScaler()

    scaled_data = scale.fit_transform(df_var)

    dmso_mean = np.mean(scaled_data, axis=0)

    ## Applying whitening transformation on Z normalized features
    

    AW = whitening_transform(scaled_data - dmso_mean, REG_PARAM, rotate=False)
    
    wh_profile = whiten(scaled_data, dmso_mean, AW)

    
    reducer = umap.UMAP()
    embedding = reducer.fit_transform(wh_profile)
    test = pd.DataFrame(embedding, columns= ['UMAP-1', 'UMAP-2'])
    comb = test.merge(metadata, left_index=True, right_index=True)  
  
    wh_umap.append(comb)
   
whitened_umap = pd.concat(wh_umap) 
whitened_umap
# Out:
#          UMAP-1    UMAP-2      Metadata_FileName_OrigMito  \
# 0     -3.287376  1.624753  r01c01f01p01-ch5sk1fk1fl1.tiff
# 1     -0.851889  1.134359  r01c01f01p01-ch5sk1fk1fl1.tiff
# 2     -2.543740 -0.086352  r01c01f01p01-ch5sk1fk1fl1.tiff
# 3     -3.168851 -1.525910  r01c01f01p01-ch5sk1fk1fl1.tiff
# 4     -2.280345 -1.118077  r01c01f01p01-ch5sk1fk1fl1.tiff
# ...         ...       ...                             ...
# 56734 -1.986750  0.316718  r10c18f09p01-ch5sk1fk1fl1.tiff
# 56735 -1.816253 -0.328651  r10c18f09p01-ch5sk1fk1fl1.tiff
# 56736 -1.764821  0.006204  r10c18f09p01-ch5sk1fk1fl1.tiff
# 56737 -1.949298 -0.437331  r10c18f09p01-ch5sk1fk1fl1.tiff
# 56738 -2.204952 -0.390892  r10c18f09p01-ch5sk1fk1fl1.tiff
#
#              Metadata_FileName_OrigER  \
# 0      r01c01f01p01-ch2sk1fk1fl1.tiff
# 1      r01c01f01p01-ch2sk1fk1fl1.tiff
# 2      r01c01f01p01-ch2sk1fk1fl1.tiff
# 3      r01c01f01p01-ch2sk1fk1fl1.tiff
# 4      r01c01f01p01-ch2sk1fk1fl1.tiff
# ...                               ...
# 56734  r10c18f09p01-ch2sk1fk1fl1.tiff
# 56735  r10c18f09p01-ch2sk1fk1fl1.tiff
# 56736  r10c18f09p01-ch2sk1fk1fl1.tiff
# 56737  r10c18f09p01-ch2sk1fk1fl1.tiff
# 56738  r10c18f09p01-ch2sk1fk1fl1.tiff
#
#                                 Metadata_PathName_OrigER  Metadata_mg_per_ml  \
# 0      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...                 NaN
# 1      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...                 NaN
# 2      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...                 NaN
# 3      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...                 NaN
# 4      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...                 NaN
# ...                                                  ...                 ...
# 56734  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...                 NaN
# 56735  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...                 NaN
# 56736  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...                 NaN
# 56737  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...                 NaN
# 56738  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...                 NaN
#
#                                Metadata_PathName_OrigDNA  \
# 0      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 1      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 2      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 3      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 4      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# ...                                                  ...
# 56734  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 56735  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 56736  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 56737  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 56738  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
#
#                                Metadata_PathName_OrigRNA  \
# 0      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 1      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 2      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 3      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 4      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# ...                                                  ...
# 56734  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 56735  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 56736  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 56737  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 56738  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
#
#                               Metadata_PathName_OrigMito  \
# 0      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 1      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 2      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 3      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 4      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# ...                                                  ...
# 56734  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 56735  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 56736  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 56737  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 56738  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
#
#             Metadata_FileName_OrigDNA  ...       Metadata_FileName_OrigAGP  \
# 0      r01c01f01p01-ch1sk1fk1fl1.tiff  ...  r01c01f01p01-ch4sk1fk1fl1.tiff
# 1      r01c01f01p01-ch1sk1fk1fl1.tiff  ...  r01c01f01p01-ch4sk1fk1fl1.tiff
# 2      r01c01f01p01-ch1sk1fk1fl1.tiff  ...  r01c01f01p01-ch4sk1fk1fl1.tiff
# 3      r01c01f01p01-ch1sk1fk1fl1.tiff  ...  r01c01f01p01-ch4sk1fk1fl1.tiff
# 4      r01c01f01p01-ch1sk1fk1fl1.tiff  ...  r01c01f01p01-ch4sk1fk1fl1.tiff
# ...                               ...  ...                             ...
# 56734  r10c18f09p01-ch1sk1fk1fl1.tiff  ...  r10c18f09p01-ch4sk1fk1fl1.tiff
# 56735  r10c18f09p01-ch1sk1fk1fl1.tiff  ...  r10c18f09p01-ch4sk1fk1fl1.tiff
# 56736  r10c18f09p01-ch1sk1fk1fl1.tiff  ...  r10c18f09p01-ch4sk1fk1fl1.tiff
# 56737  r10c18f09p01-ch1sk1fk1fl1.tiff  ...  r10c18f09p01-ch4sk1fk1fl1.tiff
# 56738  r10c18f09p01-ch1sk1fk1fl1.tiff  ...  r10c18f09p01-ch4sk1fk1fl1.tiff
#
#                           Metadata_PathName_CellOutlines  \
# 0      /home/ubuntu/local_output/SQ00015142-A01-1/out...
# 1      /home/ubuntu/local_output/SQ00015142-A01-1/out...
# 2      /home/ubuntu/local_output/SQ00015142-A01-1/out...
# 3      /home/ubuntu/local_output/SQ00015142-A01-1/out...
# 4      /home/ubuntu/local_output/SQ00015142-A01-1/out...
# ...                                                  ...
# 56734  /home/ubuntu/local_output/SQ00015201-J18-9/out...
# 56735  /home/ubuntu/local_output/SQ00015201-J18-9/out...
# 56736  /home/ubuntu/local_output/SQ00015201-J18-9/out...
# 56737  /home/ubuntu/local_output/SQ00015201-J18-9/out...
# 56738  /home/ubuntu/local_output/SQ00015201-J18-9/out...
#
#                                Metadata_PathName_OrigAGP  \
# 0      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 1      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 2      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 3      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 4      /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# ...                                                  ...
# 56734  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 56735  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 56736  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 56737  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
# 56738  /home/ubuntu/bucket/projects/2015_10_05_DrugRe...
#
#       Metadata_Cells_Location_Center_X  Metadata_Cells_Location_Center_Y  \
# 0                          1067.457429                         42.581605
# 1                          1630.743241                         50.941281
# 2                          1393.753817                         38.007687
# 3                           916.033858                         79.142099
# 4                           782.841473                         94.477015
# ...                                ...                               ...
# 56734                      2066.557456                       2058.100710
# 56735                      1245.527711                       2088.258099
# 56736                      1603.725348                       2095.471627
# 56737                      1681.360234                       2106.509057
# 56738                      1820.590386                       2126.750555
#
#       Metadata_Nuclei_Location_Center_X  Metadata_Nuclei_Location_Center_Y  \
# 0                           1048.957763                          25.202055
# 1                           1616.007126                          36.282067
# 2                           1386.618348                          48.790310
# 3                            913.591124                          59.854142
# 4                            795.054333                          72.157162
# ...                                 ...                                ...
# 56734                       2081.862720                        2063.554698
# 56735                       1210.574634                        2075.303638
# 56736                       1612.100068                        2092.849727
# 56737                       1705.305275                        2114.365400
# 56738                       1814.662765                        2121.912765
#
#       Metadata_Cytoplasm_Location_Center_X  \
# 0                              1071.531566
# 1                              1635.967613
# 2                              1396.049176
# 3                               916.564685
# 4                               779.381538
# ...                                    ...
# 56734                          2058.750792
# 56735                          1256.602468
# 56736                          1599.693603
# 56737                          1667.626751
# 56738                          1832.497587
#
#       Metadata_Cytoplasm_Location_Center_Y Metadata_ObjectNumber
# 0                                46.386540                     1
# 1                                56.161364                     2
# 2                                34.604377                     3
# 3                                83.450739                     4
# 4                               100.793610                     5
# ...                                    ...                   ...
# 56734                          2055.298951                   281
# 56735                          2092.359577                   282
# 56736                          2096.749686                   283
# 56737                          2101.951486                   284
# 56738                          2136.304584                   285
#
# [319967 rows x 28 columns]

# %% [markdown]
# ## Plotting

# %%
p = gg.ggplot(whitened_umap, gg.aes(x='UMAP-1', y='UMAP-2', color= 'Metadata_Plate')) + \
    gg.geom_point(size = 0.003) + \
    gg.xlab("UMAP-1") + \
    gg.ylab("UMAP-2") + \
    gg.ggtitle("UMAP visualization of DMSO's single cell data (Whitened_data)") + \
    gg.theme_bw() + \
    gg.scale_colour_manual(name= "Platemap", labels=['SQ00015201', 'SQ00015142', 'SQ00015143', 'SQ00015144', 'SQ00015145'], 
                           values = ["#d95f0e", "#fec44f", "#2c7fb8", "#7fcdbb", '#636363'])
    
   


    

gg.ggsave(filename='Modes_DMSO_UMAP_whitened.png', plot = p, path = outpath)

p
# Out:
# /Users/habbasi/plotnine/plotnine/ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
# /Users/habbasi/plotnine/plotnine/ggplot.py:730: PlotnineWarning: Filename: /Users/habbasi/Documents/Github/broadinstitute/2020-06-01-Evidence-of-state-switching-in-single-cell-drug-response-Broad/Figures/Modes_DMSO_UMAP_whitened.png
# <ggplot: (7038837657)>

# %% [markdown]
# ## Variables

# %%
metalist = ['Image_FileName_OrigMito',
 'Image_FileName_OrigER',
 'Image_PathName_OrigER',
 'Metadata_mg_per_ml',
 'Image_PathName_OrigDNA',
 'Image_PathName_OrigRNA',
 'Image_PathName_OrigMito',
 'Image_FileName_OrigDNA',
 'Image_FileName_OrigRNA',
 'Metadata_broad_sample',
 'Image_Metadata_Well',
 'Metadata_plate_map_name',
 'Metadata_mmoles_per_liter',
 'Image_FileName_CellOutlines',
 'Image_Metadata_Site',
 'Metadata_Plate',
 'Image_FileName_OrigAGP',
 'Image_PathName_CellOutlines',
 'Image_PathName_OrigAGP',
 'Cells_Location_Center_X',
 'Cells_Location_Center_Y',
 'Nuclei_Location_Center_X',
 'Nuclei_Location_Center_Y',
 'Cytoplasm_Location_Center_X',
 'Cytoplasm_Location_Center_Y',
 'ObjectNumber']

metadata = (dmso.loc[:, metalist]
            .rename(columns={'Cells_Location_Center_X':'Metadata_Cells_Location_Center_X',
                            'Cells_Location_Center_Y':'Metadata_Cells_Location_Center_Y',
                            'Nuclei_Location_Center_X':'Metadata_Nuclei_Location_Center_X',
                            'Nuclei_Location_Center_Y':'Metadata_Nuclei_Location_Center_Y',
                            'Cytoplasm_Location_Center_X':'Metadata_Cytoplasm_Location_Center_X',
                            'Cytoplasm_Location_Center_Y':'Metadata_Cytoplasm_Location_Center_Y',
                            'ObjectNumber': 'Metadata_ObjectNumber'})
           )
metadata.columns = metadata.columns.str.replace('Image_', "Metadata_")




# def difference(list1, list2):
#     return list(set(list1) ^ set(list2))

# ## Excluding Features

# exclude_BF = dmso.filter(regex='Center|ObjectNumber|TableNumber|Location|Count|Parent|Image|Metadata|Granularity_14|Granularity_15|Granularity_16|Manders|RWC|Costes').columns.tolist()
# var_left = difference(dmso.columns, exclude_BF)

# df_var = dmso.loc[:, var_left]

# df_var.head()

df_var = dmso.loc[:, featlist]
df_var.head()

metadata.columns

# %% [markdown]
# ## Data Preprocessing

# %%
from sklearn.preprocessing import StandardScaler

scale = StandardScaler()

# Z normalized features
scaled_data = scale.fit_transform(df_var.values)

df = pd.DataFrame(scaled_data, columns= df_var.columns)
# dm = metadata.merge(df, left_index=True, right_index=True)
# dm.head()

df.values

# %%
dmso.shape

# %%
# from sklearn.feature_selection import VarianceThreshold

# constant_filter = VarianceThreshold(threshold=0.005)
# constant_filter.fit(df_var.values)
# constant_columns = [col for col in df_var.columns
#                     if col not in df_var.columns[constant_filter.get_support()]]

# len(sorted(constant_columns))

# %%
import umap

reducer = umap.UMAP()
embedding = reducer.fit_transform(df.values)
embedding.shape

# %%
test = pd.DataFrame(embedding, columns= ['UMAP-1', 'UMAP-2'])
combined = test.merge(dmso.loc[:, metalist], left_index=True, right_index=True)

# %%
combined.columns

# %%
p = gg.ggplot(combined, gg.aes(x='UMAP-1', y='UMAP-2', color= 'Image_Metadata_Well')) + \
    gg.geom_point(size = 0.2) + \
    gg.xlab("UMAP-1") + \
    gg.ylab("UMAP-2") + \
    gg.ggtitle("UMAP Uniform Manifold Approximation and Projection_perdose_aggregation") #+ \
    #gg.scale_colour_manual(name= "Platemap", labels=['Drug_Controls', 'Drug_Treatments', 'Target_Controls', 'Target_Treatments'], values = ["#d95f0e", "#fec44f", "#2c7fb8", "#7fcdbb"])
   


    

#ggsave(filename='Drug_target_UMAP.png', plot = p, path = '/Users/habbasi/Desktop/')

p
